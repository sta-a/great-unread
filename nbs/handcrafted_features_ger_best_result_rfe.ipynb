# %%
random_seed = 42
import numpy as np; np.random.seed(random_seed)
import xgboost
from sklearn.metrics import mean_absolute_error
import pandas as pd
from copy import deepcopy


class HyperParameterOptimizer(object):
    def __init__(self):
        self.model = None
        self.feature_importances_ = None
    
    def fit(self, _train_X, _train_y):
        print(f"Current shape of feature matrix:", _train_X.shape)
        num_boost_round = 99999

        def feval(preds, train_data):
            labels = train_data.get_label()
            return 'mae', mean_absolute_error(labels, preds)
        
        all_results = []
        for max_depth in [5]: # [5, 10, 15, 20, 25]
            for learning_rate in [0.01]:
                for colsample_bytree in [0.5]:
                    for min_child_weight in [6]: # 3, 6, 8, 12
                        train_X = deepcopy(_train_X)
                        train_y = deepcopy(_train_y)
                        dtrain = xgboost.DMatrix(train_X, label=train_y)
                        params = {"max_depth": max_depth, "learning_rate": learning_rate, "colsample_bytree": colsample_bytree, "min_child_weight": min_child_weight, "n_jobs": -1}
                        cv_results = xgboost.cv(
                            params,
                            dtrain,
                            num_boost_round=num_boost_round,
                            seed=random_seed,
                            nfold=10,
                            feval=feval,
                            early_stopping_rounds=20,
                            verbose_eval=False
                        )
                        print(train_X.shape[1], max_depth, learning_rate, colsample_bytree, min_child_weight, np.round(float(cv_results["test-mae-mean"].iloc[len(cv_results["test-mae-mean"])-1]), 4))
                        all_results.append((max_depth, learning_rate, colsample_bytree, min_child_weight, cv_results))
        all_results_df = pd.DataFrame(all_results, columns=["max_depth", "learning_rate", "colsample_bytree", "min_child_weight", "cv_results"])
        all_results_df["best_validation_f1"] = all_results_df["cv_results"].apply(lambda x: x.iloc[len(x)-1]["test-mae-mean"])
        all_results_df = all_results_df.sort_values(by="best_validation_f1", ascending=False).reset_index(drop=True)
        best_parameters = all_results_df.iloc[0]
        best_max_depth = int(best_parameters["max_depth"])
        best_learning_rate = float(best_parameters["learning_rate"])
        best_colsample_bytree = float(best_parameters["colsample_bytree"])
        best_min_child_weight = float(best_parameters["min_child_weight"])
        best_validation_f1 = float(best_parameters["best_validation_f1"])
        best_num_boost_round = int(len(best_parameters["cv_results"]))
        
        print("Current best max_depth:", best_max_depth)
        print("Current best learning_rate:", best_learning_rate)
        print("Current best colsample_bytree:", best_colsample_bytree)
        print("Current best min_child_weight:", best_min_child_weight)
        print("Current best num_boost_round:", best_num_boost_round)
        params = {"max_depth": best_max_depth, "learning_rate": best_learning_rate, "colsample_bytree": best_colsample_bytree, "min_child_weight": best_min_child_weight, "n_jobs": -1}
        
        train_X = deepcopy(_train_X)
        train_y = deepcopy(_train_y)
        dtrain = xgboost.DMatrix(train_X, label=train_y)
        model = xgboost.train(params,
                              dtrain,
                              num_boost_round=best_num_boost_round,
                              verbose_eval=False)
        feature_importances = model.get_score(importance_type='gain')
        feature_importances_list = []
        for i in range(train_X.shape[1]):
            current_key = f'f{i}'
            if current_key in feature_importances:
                feature_importances_list.append(feature_importances[current_key])
            else:
                feature_importances_list.append(0.0)
        print(f"Current best validation f1 score is {np.round(best_validation_f1, 4)}")
        print("############################")
        self.model = model
        self.feature_importances_ = np.array(feature_importances_list)
        return self
    
    def predict(self, X):
        return self.model.predict(xgboost.DMatrix(X))

    def predict_proba(self, X):
        return self.predict(X)
    
    def decision_function(self, X):
        return self.predict(X)
    
    def transform(self, X):
        return self.predict(X)

    def score(self, X=None, y=None):
        return 0.0

    def get_params(self, deep=True):
        return {}

    def set_params(self, **params):
        return self

    def _get_tags(self):
        return {"allow_nan": True}

# %%
from sklearn.feature_selection import RFE
import sys
sys.path.insert(0, "../src/")
import numpy as np
import pandas as pd
from utils import read_labels

labels_dir = "../data/labels/"
lang = "ger"
labels = read_labels(labels_dir, lang)

extracted_features_dir = "../data/extracted_features/"

book_and_averaged_chunk_df = pd.read_csv(f"{extracted_features_dir}/{lang}/book_and_averaged_chunk_df.csv")

train_X = book_and_averaged_chunk_df.drop(columns=["book_name"])
train_X = train_X[[column for column in train_X.columns if "average_sentence_embedding" not in column]].values
# train_X = book_and_averaged_chunk_df[best_features]
train_y = book_and_averaged_chunk_df["book_name"].apply(lambda x: labels[x]).values

hpo = HyperParameterOptimizer()
rfe = RFE(hpo, step=10, n_features_to_select=10, verbose=0)
rfe.fit(train_X, train_y)
# Out:
# Current shape of feature matrix: (547, 526)
# 526 5 0.01 0.5 6 15.0445
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1779
# Current best validation f1 score is 15.0445
# ############################
# Current shape of feature matrix: (547, 516)
# 516 5 0.01 0.5 6 15.0866
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 835
# Current best validation f1 score is 15.0866
# ############################
# Current shape of feature matrix: (547, 506)
# 506 5 0.01 0.5 6 15.1443
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 687
# Current best validation f1 score is 15.1443
# ############################
# Current shape of feature matrix: (547, 496)
# 496 5 0.01 0.5 6 15.0213
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1267
# Current best validation f1 score is 15.0213
# ############################
# Current shape of feature matrix: (547, 486)
# 486 5 0.01 0.5 6 15.0045
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1004
# Current best validation f1 score is 15.0045
# ############################
# Current shape of feature matrix: (547, 476)
# 476 5 0.01 0.5 6 14.8857
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1152
# Current best validation f1 score is 14.8857
# ############################
# Current shape of feature matrix: (547, 466)
# 466 5 0.01 0.5 6 15.0296
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1092
# Current best validation f1 score is 15.0296
# ############################
# Current shape of feature matrix: (547, 456)
# 456 5 0.01 0.5 6 14.9395
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1043
# Current best validation f1 score is 14.9395
# ############################
# Current shape of feature matrix: (547, 446)
# 446 5 0.01 0.5 6 14.8876
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 761
# Current best validation f1 score is 14.8876
# ############################
# Current shape of feature matrix: (547, 436)
# 436 5 0.01 0.5 6 14.9996
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1093
# Current best validation f1 score is 14.9996
# ############################
# Current shape of feature matrix: (547, 426)
# 426 5 0.01 0.5 6 14.8576
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 941
# Current best validation f1 score is 14.8576
# ############################
# Current shape of feature matrix: (547, 416)
# 416 5 0.01 0.5 6 14.8527
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 827
# Current best validation f1 score is 14.8527
# ############################
# Current shape of feature matrix: (547, 406)
# 406 5 0.01 0.5 6 14.7929
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 918
# Current best validation f1 score is 14.7929
# ############################
# Current shape of feature matrix: (547, 396)
# 396 5 0.01 0.5 6 14.7571
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1152
# Current best validation f1 score is 14.7571
# ############################
# Current shape of feature matrix: (547, 386)
# 386 5 0.01 0.5 6 14.7036
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1532
# Current best validation f1 score is 14.7036
# ############################
# Current shape of feature matrix: (547, 376)
# 376 5 0.01 0.5 6 14.8647
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 702
# Current best validation f1 score is 14.8647
# ############################
# Current shape of feature matrix: (547, 366)
# 366 5 0.01 0.5 6 14.8133
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 900
# Current best validation f1 score is 14.8133
# ############################
# Current shape of feature matrix: (547, 356)
# 356 5 0.01 0.5 6 14.5779
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1448
# Current best validation f1 score is 14.5779
# ############################
# Current shape of feature matrix: (547, 346)
# 346 5 0.01 0.5 6 14.6132
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1150
# Current best validation f1 score is 14.6132
# ############################
# Current shape of feature matrix: (547, 336)
# 336 5 0.01 0.5 6 14.6473
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 962
# Current best validation f1 score is 14.6473
# ############################
# Current shape of feature matrix: (547, 326)
# 326 5 0.01 0.5 6 14.682
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1112
# Current best validation f1 score is 14.682
# ############################
# Current shape of feature matrix: (547, 316)
# 316 5 0.01 0.5 6 14.5857
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1160
# Current best validation f1 score is 14.5857
# ############################
# Current shape of feature matrix: (547, 306)
# 306 5 0.01 0.5 6 14.5732
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1121
# Current best validation f1 score is 14.5732
# ############################
# Current shape of feature matrix: (547, 296)
# 296 5 0.01 0.5 6 14.508
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1162
# Current best validation f1 score is 14.508
# ############################
# Current shape of feature matrix: (547, 286)
# 286 5 0.01 0.5 6 14.5645
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 995
# Current best validation f1 score is 14.5645
# ############################
# Current shape of feature matrix: (547, 276)
# 276 5 0.01 0.5 6 14.6339
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 899
# Current best validation f1 score is 14.6339
# ############################
# Current shape of feature matrix: (547, 266)
# 266 5 0.01 0.5 6 14.4859
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1064
# Current best validation f1 score is 14.4859
# ############################
# Current shape of feature matrix: (547, 256)
# 256 5 0.01 0.5 6 14.557
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1113
# Current best validation f1 score is 14.557
# ############################
# Current shape of feature matrix: (547, 246)
# 246 5 0.01 0.5 6 14.5283
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 885
# Current best validation f1 score is 14.5283
# ############################
# Current shape of feature matrix: (547, 236)
# 236 5 0.01 0.5 6 14.4174
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 779
# Current best validation f1 score is 14.4174
# ############################
# Current shape of feature matrix: (547, 226)
# 226 5 0.01 0.5 6 14.4862
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 681
# Current best validation f1 score is 14.4862
# ############################
# Current shape of feature matrix: (547, 216)
# 216 5 0.01 0.5 6 14.4117
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1017
# Current best validation f1 score is 14.4117
# ############################
# Current shape of feature matrix: (547, 206)
# 206 5 0.01 0.5 6 14.4739
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1086
# Current best validation f1 score is 14.4739
# ############################
# Current shape of feature matrix: (547, 196)
# 196 5 0.01 0.5 6 14.3918
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 943
# Current best validation f1 score is 14.3918
# ############################
# Current shape of feature matrix: (547, 186)
# 186 5 0.01 0.5 6 14.467
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 922
# Current best validation f1 score is 14.467
# ############################
# Current shape of feature matrix: (547, 176)
# 176 5 0.01 0.5 6 14.182
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1086
# Current best validation f1 score is 14.182
# ############################
# Current shape of feature matrix: (547, 166)
# 166 5 0.01 0.5 6 14.2589
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 871
# Current best validation f1 score is 14.2589
# ############################
# Current shape of feature matrix: (547, 156)
# 156 5 0.01 0.5 6 14.2138
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 865
# Current best validation f1 score is 14.2138
# ############################
# Current shape of feature matrix: (547, 146)
# 146 5 0.01 0.5 6 14.3121
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 809
# Current best validation f1 score is 14.3121
# ############################
# Current shape of feature matrix: (547, 136)
# 136 5 0.01 0.5 6 14.2797
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 754
# Current best validation f1 score is 14.2797
# ############################
# Current shape of feature matrix: (547, 126)
# 126 5 0.01 0.5 6 14.055
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 916
# Current best validation f1 score is 14.055
# ############################
# Current shape of feature matrix: (547, 116)
# 116 5 0.01 0.5 6 14.0403
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 897
# Current best validation f1 score is 14.0403
# ############################
# Current shape of feature matrix: (547, 106)
# 106 5 0.01 0.5 6 13.9179
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 830
# Current best validation f1 score is 13.9179
# ############################
# Current shape of feature matrix: (547, 96)
# 96 5 0.01 0.5 6 13.9277
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 734
# Current best validation f1 score is 13.9277
# ############################
# Current shape of feature matrix: (547, 86)
# 86 5 0.01 0.5 6 13.9556
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 756
# Current best validation f1 score is 13.9556
# ############################
# Current shape of feature matrix: (547, 76)
# 76 5 0.01 0.5 6 13.9639
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 766
# Current best validation f1 score is 13.9639
# ############################
# Current shape of feature matrix: (547, 66)
# 66 5 0.01 0.5 6 14.0706
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 692
# Current best validation f1 score is 14.0706
# ############################
# Current shape of feature matrix: (547, 56)
# 56 5 0.01 0.5 6 14.0041
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 632
# Current best validation f1 score is 14.0041
# ############################
# Current shape of feature matrix: (547, 46)
# 46 5 0.01 0.5 6 14.2976
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 627
# Current best validation f1 score is 14.2976
# ############################
# Current shape of feature matrix: (547, 36)
# 36 5 0.01 0.5 6 14.435
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 439
# Current best validation f1 score is 14.435
# ############################
# Current shape of feature matrix: (547, 26)
# 26 5 0.01 0.5 6 14.4762
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 371
# Current best validation f1 score is 14.4762
# ############################
# Current shape of feature matrix: (547, 16)
# 16 5 0.01 0.5 6 14.7209
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 384
# Current best validation f1 score is 14.7209
# ############################
# Current shape of feature matrix: (547, 10)
# 10 5 0.01 0.5 6 15.287
# Current best max_depth: 5
# Current best learning_rate: 0.01
# Current best colsample_bytree: 0.5
# Current best min_child_weight: 6.0
# Current best num_boost_round: 317
# Current best validation f1 score is 15.287
# ############################
# RFE(estimator=<__main__.HyperParameterOptimizer object at 0x11a314f40>,
#     n_features_to_select=10, step=10)

# %%
num_boost_round = 734

# %%
book_and_averaged_chunk_df = pd.read_csv(f"{extracted_features_dir}/{lang}/book_and_averaged_chunk_df.csv")
book_and_averaged_chunk_df = book_and_averaged_chunk_df.drop(columns=["book_name"])
book_and_averaged_chunk_df = book_and_averaged_chunk_df[[column for column in book_and_averaged_chunk_df.columns if "average_sentence_embedding" not in column]]
best_features = book_and_averaged_chunk_df.columns[np.argwhere((rfe.ranking_ <= 10) == True).T[0]].tolist()
print(len(best_features))
print(best_features)
# Out:
# 96
# ['doc2vec_intra_textual_variance', 'doc2vec_stepwise_distance', '50_most_common_1gram_stopword_True_und', '50_most_common_1gram_stopword_True_die', '50_most_common_1gram_stopword_True_dem', '50_most_common_1gram_stopword_True_von', '50_most_common_1gram_stopword_True_an', '50_most_common_1gram_stopword_True_wenn', '50_most_common_1gram_stopword_True_aus', '50_most_common_1gram_stopword_True_hatte', '50_most_common_1gram_stopword_True_da', '50_most_common_1gram_stopword_True_sein', '50_most_common_1gram_stopword_True_man', '50_most_common_1gram_stopword_True_fuer', '50_most_common_1gram_stopword_True_wir', '50_most_common_2gram_stopword_True_<BOS> <EOS>', '50_most_common_2gram_stopword_True_mit dem', '50_most_common_2gram_stopword_True_und der', '50_most_common_2gram_stopword_True_auf dem', '50_most_common_2gram_stopword_True_<BOS> ein', '50_most_common_2gram_stopword_True_<BOS> denn', '50_most_common_2gram_stopword_True_und das', '50_most_common_2gram_stopword_True_<BOS> ja', '50_most_common_3gram_stopword_True_<BOS> <BOS> so', '50_most_common_3gram_stopword_True_<BOS> <BOS> ja', '50_most_common_3gram_stopword_True_<BOS> <BOS> nun', '50_most_common_3gram_stopword_True_<BOS> <BOS> mit', '50_most_common_3gram_stopword_True_<BOS> <BOS> auch', '50_most_common_3gram_stopword_True_<BOS> <BOS> eine', '50_most_common_3gram_stopword_True_<BOS> <BOS> doch', '50_most_common_1gram_stopword_False_fuer', '50_most_common_1gram_stopword_False_herr', '50_most_common_1gram_stopword_False_liebe', '50_most_common_1gram_stopword_False_sagen', '50_most_common_1gram_stopword_False_stand', '50_most_common_1gram_stopword_False_alte', '50_most_common_1gram_stopword_False_waehrend', '50_most_common_1gram_stopword_False_wissen', '50_most_common_1gram_stopword_False_fast', '50_most_common_1gram_stopword_False_hielt', '50_most_common_2gram_stopword_False_seyn <EOS>', '50_most_common_2gram_stopword_False_<BOS> fuer', '50_most_common_2gram_stopword_False_bringen <EOS>', '50_most_common_2gram_stopword_False_<BOS> waehrend', '50_most_common_2gram_stopword_False_finden <EOS>', '50_most_common_2gram_stopword_False_liebe <EOS>', '50_most_common_2gram_stopword_False_vater <EOS>', '50_most_common_2gram_stopword_False_<BOS> frau', '50_most_common_3gram_stopword_False_seyn <EOS> <EOS>', '50_most_common_3gram_stopword_False_<BOS> <BOS> fuer', '50_most_common_3gram_stopword_False_<BOS> <BOS> waehrend', '50_most_common_3gram_stopword_False_liebe <EOS> <EOS>', '50_most_common_3gram_stopword_False_vater <EOS> <EOS>', '50_most_common_3gram_stopword_False_<BOS> <BOS> frau', 'lda_topic_10', 'tfidf_alte', 'tfidf_liebe', 'tfidf_herr', 'tfidf_ueber', 'tfidf_herz', 'tfidf_fragte', 'tfidf_hielt', 'tfidf_leute', 'keyness_alte', 'keyness_waehrend', 'keyness_liebe', 'keyness_herr', 'keyness_fast', 'keyness_stand', 'keyness_sagen', 'doc2vec_chunk_embedding_2', 'doc2vec_chunk_embedding_7', 'doc2vec_chunk_embedding_19', 'doc2vec_chunk_embedding_22', 'doc2vec_chunk_embedding_23', 'doc2vec_chunk_embedding_24', 'doc2vec_chunk_embedding_28', 'doc2vec_chunk_embedding_31', 'doc2vec_chunk_embedding_36', 'doc2vec_chunk_embedding_38', 'doc2vec_chunk_embedding_40', 'doc2vec_chunk_embedding_43', 'doc2vec_chunk_embedding_44', 'doc2vec_chunk_embedding_46', 'doc2vec_chunk_embedding_49', 'doc2vec_chunk_embedding_61', 'doc2vec_chunk_embedding_68', 'doc2vec_chunk_embedding_71', 'doc2vec_chunk_embedding_75', 'doc2vec_chunk_embedding_82', 'doc2vec_chunk_embedding_84', 'doc2vec_chunk_embedding_85', 'doc2vec_chunk_embedding_93', 'doc2vec_chunk_embedding_95', 'doc2vec_chunk_embedding_97', 'doc2vec_chunk_embedding_100']

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

book_and_averaged_chunk_df = pd.read_csv(f"{extracted_features_dir}/{lang}/book_and_averaged_chunk_df.csv")
book_names = book_and_averaged_chunk_df["book_name"].values

book_and_averaged_chunk_df = book_and_averaged_chunk_df.drop(columns=["book_name"])
book_and_averaged_chunk_df = book_and_averaged_chunk_df[[column for column in book_and_averaged_chunk_df.columns if "average_sentence_embedding" not in column]]
best_features = book_and_averaged_chunk_df.columns[np.argwhere((rfe.ranking_ <= 7) == True).T[0]].tolist()
book_and_averaged_chunk_df = book_and_averaged_chunk_df[best_features]

df = book_and_averaged_chunk_df
df["y"] = np.array([labels[book_name] for book_name in book_names])
df["book_name"] = book_names

all_predictions = []
all_labels = []
train_mses = []
train_maes = []
validation_mses = []
validation_maes = []

book_names_splitted = np.array_split(book_names, 10)
for index, split in enumerate(book_names_splitted):
    train_df = df[~df["book_name"].isin(split)]
    validation_df = df[df["book_name"].isin(split)]
    train_X = train_df.drop(columns=["y", "book_name"]).values
    train_y = train_df["y"].values.ravel()
    validation_X = validation_df.drop(columns=["y", "book_name"]).values
    validation_y = validation_df["y"].values.ravel()
    dtrain = xgboost.DMatrix(train_X, label=train_y)
    params = {"max_depth": 5, "learning_rate": 0.01, "colsample_bytree": 0.5, "min_child_weight": 6.0, "n_jobs": -1}
    model = xgboost.train(
        params,
        dtrain,
        num_boost_round=num_boost_round
    )

    train_books = deepcopy(train_df[["book_name", "y"]])
    train_books["yhat"] = model.predict(xgboost.DMatrix(train_X))
    validation_books = deepcopy(validation_df[["book_name", "y"]])
    validation_books["yhat"] = model.predict(xgboost.DMatrix(validation_X))

    train_books = train_books.groupby("book_name").mean()
    validation_books = validation_books.groupby("book_name").mean()

    train_y = train_books["y"].tolist()
    train_yhat = train_books["yhat"].tolist()
    validation_y = validation_books["y"].tolist()
    validation_yhat = validation_books["yhat"].tolist()

    all_labels.extend(validation_y)
    all_predictions.extend(validation_yhat)

    train_mse = mean_squared_error(train_y, train_yhat)
    train_mae = mean_absolute_error(train_y, train_yhat)
    validation_mse = mean_squared_error(validation_y, validation_yhat)
    validation_mae = mean_absolute_error(validation_y, validation_yhat)
    train_mses.append(train_mse)
    train_maes.append(train_mae)
    validation_mses.append(validation_mse)
    validation_maes.append(validation_mae)
    print(f"Fold: {index+1}, TrainMSE: {np.round(train_mse, 3)}, TrainMAE: {np.round(train_mae, 3)}, ValMSE: {np.round(validation_mse, 3)}, ValMAE: {np.round(validation_mae, 3)}")
all_labels = np.array(all_labels)
all_predictions = np.array(all_predictions)

mean_train_mse = np.mean(train_mses)
mean_train_mae = np.mean(train_maes)
mean_validation_mse = np.mean(validation_mses)
mean_validation_mae = np.mean(validation_maes)


print("------")
print(f"Mean scores, TrainMSE: {np.round(mean_train_mse, 3)}, TrainMAE: {np.round(mean_train_mae, 3)}, ValMSE: {np.round(mean_validation_mse, 3)}, ValMAE: {np.round(mean_validation_mae, 3)}")

plt.figure(figsize=(18, 6))
plt.scatter(all_labels, all_predictions)
plt.xlabel("Ground Truths")
plt.ylabel("Predictions")

plt.show();
# Out:
# Fold: 1, TrainMSE: 46.084, TrainMAE: 5.124, ValMSE: 354.968, ValMAE: 15.168
# Fold: 2, TrainMSE: 41.971, TrainMAE: 4.901, ValMSE: 253.86, ValMAE: 12.209
# Fold: 3, TrainMSE: 48.328, TrainMAE: 5.177, ValMSE: 243.503, ValMAE: 11.621
# Fold: 4, TrainMSE: 40.861, TrainMAE: 4.773, ValMSE: 389.975, ValMAE: 15.753
# Fold: 5, TrainMSE: 47.407, TrainMAE: 5.149, ValMSE: 410.08, ValMAE: 16.341
# Fold: 6, TrainMSE: 46.445, TrainMAE: 5.042, ValMSE: 296.299, ValMAE: 13.496
# Fold: 7, TrainMSE: 50.15, TrainMAE: 5.253, ValMSE: 390.779, ValMAE: 15.174
# Fold: 8, TrainMSE: 42.994, TrainMAE: 4.905, ValMSE: 310.003, ValMAE: 13.763
# Fold: 9, TrainMSE: 47.727, TrainMAE: 5.141, ValMSE: 279.333, ValMAE: 13.317
# Fold: 10, TrainMSE: 41.368, TrainMAE: 4.774, ValMSE: 411.966, ValMAE: 16.3
# ------
# Mean scores, TrainMSE: 45.333, TrainMAE: 5.024, ValMSE: 334.077, ValMAE: 14.314
