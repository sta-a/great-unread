# %%
'''
handcrafted_features_{lang}_multiple_experiments: The notebook with SVR + XGBoost and Lasso experiments.
'''

# %%
import sys
sys.path.insert(0, "../src/")
import numpy as np
import pandas as pd

extracted_features_dir = "../data/extracted_features/"
labels_dir = "../data/labels/"
lang = "ger"

book_df = pd.read_csv(f"{extracted_features_dir}/{lang}/book_df.csv")
book_and_averaged_chunk_df = pd.read_csv(f"{extracted_features_dir}/{lang}/book_and_averaged_chunk_df.csv")
chunk_df = pd.read_csv(f"{extracted_features_dir}/{lang}/chunk_df.csv")
chunk_and_copied_book_df = pd.read_csv(f"{extracted_features_dir}/{lang}/chunk_and_copied_book_df.csv")

# %%
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.impute import KNNImputer
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from xgboost import XGBRegressor
import matplotlib.pyplot as plt
from copy import deepcopy
from utils import read_labels
from sklearn.metrics import mean_squared_error, mean_absolute_error

labels = read_labels(labels_dir)

class Experiment(object):
    def __init__(self, features, drop_columns_including, dimensionality_reduction, model, verbose):
        assert features in ["book", "chunk", "book_and_averaged_chunk", "chunk_and_copied_book"]
        assert isinstance(drop_columns_including, list)
        for i in drop_columns_including:
            assert isinstance(i, str)
        assert model in ["xgboost", "svr", "lasso"]
        assert (dimensionality_reduction in ["ss_pca_0_95", "k_best_f_reg_0_10", "k_best_mutual_info_0_10"]) or (dimensionality_reduction is None)
        self.features = features
        self.labels = labels
        self.drop_columns_including = drop_columns_including
        self.dimensionality_reduction = dimensionality_reduction
        self.model = model
        self.verbose = verbose

        if features == "book":
            self.df = deepcopy(book_df)
        elif features == "chunk":
            self.df = deepcopy(chunk_df)
        elif features == "chunk_and_copied_book":
            self.df = deepcopy(chunk_and_copied_book_df)
        elif features == "book_and_averaged_chunk":
            self.df = deepcopy(book_and_averaged_chunk_df)

        columns_before_drop = set(self.df.columns)
        self.df = self.df[[column for column in self.df.columns if not self._drop_column(column)]].reset_index(drop=True)
        columns_after_drop = set(self.df.columns)
        if self.verbose:
            print(f"Dropped {len(columns_before_drop - columns_after_drop)} columns.")
        self.df.loc[:, "y"] = self.df.book_name.apply(lambda x: self.labels[x]).tolist()

    def _drop_column(self, column):
        for string in self.drop_columns_including:
            if string in column:
                return True
        return False
    
    def _custom_pca(self, train_X):
        for i in range(5, train_X.shape[1], int((train_X.shape[1] - 5) / 10)):
            pca = PCA(n_components=i)
            new_train_X = pca.fit_transform(train_X)
            if pca.explained_variance_ratio_.sum() >= 0.95:
                break
        return new_train_X, pca

    def _select_features(self, train_X, train_y, validation_X):
        if self.dimensionality_reduction == "ss_pca_0_95":
            ss = StandardScaler()
            train_X = ss.fit_transform(train_X)
            validation_X = ss.transform(validation_X)
            train_X, pca = self._custom_pca(train_X)
            validation_X = pca.transform(validation_X)
        elif self.dimensionality_reduction == "k_best_f_reg_0_10":
            k_best = SelectKBest(f_regression, k=np.minimum(int(0.10 * train_X.shape[0]), train_X.shape[1]))
            train_X = k_best.fit_transform(train_X, train_y)
            validation_X = k_best.transform(validation_X)
        elif self.dimensionality_reduction == "k_best_mutual_info_0_10":
            k_best = SelectKBest(mutual_info_regression, k=np.minimum(int(0.10 * train_X.shape[0]), train_X.shape[1]))
            train_X = k_best.fit_transform(train_X, train_y)
            validation_X = k_best.transform(validation_X)
        elif self.dimensionality_reduction is None:
            pass
        return train_X, validation_X
    
    def _impute(self, train_X, validation_X):
        imputer = KNNImputer()
        train_X = imputer.fit_transform(train_X)
        validation_X = imputer.transform(validation_X)
        return train_X, validation_X
    
    def _get_model(self):
        # if any of these performs better than others, we can try to tune the hyperparameters
        # but I think for now it's more important to see which approach performs better
        # chunk based or doc based
        # use dimensionality reduction or not...
        if self.model == "xgboost":
            return XGBRegressor(n_estimators=1000, max_depth=4, learning_rate=0.01, colsample_bytree=0.33, min_child_weight=6)
        elif self.model == "svr":
            return SVR()
        elif self.model == "lasso":
            return Lasso()
            
    def run(self):
        all_predictions = []
        all_labels = []
        train_mses = []
        train_maes = []
        validation_mses = []
        validation_maes = []

        df = self.df
        book_names = df['book_name'].unique()
        book_names_splitted = np.array_split(book_names, 10)
        for index, split in enumerate(book_names_splitted):
            train_df = df[~df["book_name"].isin(split)]
            validation_df = df[df["book_name"].isin(split)]
            train_X = train_df.drop(columns=["y", "book_name"]).values
            train_y = train_df["y"].values.ravel()
            validation_X = validation_df.drop(columns=["y", "book_name"]).values
            validation_y = validation_df["y"].values.ravel()
            train_X, validation_X = self._impute(train_X, validation_X)
            if self.verbose:
                print(f"train_X.shape before {self.dimensionality_reduction}: {train_X.shape}, validation_X.shape before {self.dimensionality_reduction}: {validation_X.shape}")
            train_X, validation_X = self._select_features(train_X, train_y, validation_X)
            if self.verbose:
                print(f"train_X.shape after {self.dimensionality_reduction}: {train_X.shape}, validation_X.shape after {self.dimensionality_reduction}: {validation_X.shape}")
            model = self._get_model()
            model.fit(train_X, train_y)
            
            train_books = deepcopy(train_df[["book_name", "y"]])
            train_books["yhat"] = model.predict(train_X)
            validation_books = deepcopy(validation_df[["book_name", "y"]])
            validation_books["yhat"] = model.predict(validation_X)
            
            train_books = train_books.groupby("book_name").mean()
            validation_books = validation_books.groupby("book_name").mean()
            
            train_y = train_books["y"].tolist()
            train_yhat = train_books["yhat"].tolist()
            validation_y = validation_books["y"].tolist()
            validation_yhat = validation_books["yhat"].tolist()
            
            all_labels.extend(validation_y)
            all_predictions.extend(validation_yhat)
            
            train_mse = mean_squared_error(train_y, train_yhat)
            train_mae = mean_absolute_error(train_y, train_yhat)
            validation_mse = mean_squared_error(validation_y, validation_yhat)
            validation_mae = mean_absolute_error(validation_y, validation_yhat)
            train_mses.append(train_mse)
            train_maes.append(train_mae)
            validation_mses.append(validation_mse)
            validation_maes.append(validation_mae)
            if self.verbose:
                print(f"Fold: {index+1}, TrainMSE: {np.round(train_mse, 3)}, TrainMAE: {np.round(train_mae, 3)}, ValMSE: {np.round(validation_mse, 3)}, ValMAE: {np.round(validation_mae, 3)}")
        all_labels = np.array(all_labels)
        all_predictions = np.array(all_predictions)

        mean_train_mse = np.mean(train_mses)
        mean_train_mae = np.mean(train_maes)
        mean_validation_mse = np.mean(validation_mses)
        mean_validation_mae = np.mean(validation_maes)
        
        if self.verbose:
            print("------")
            print(f"Mean scores, TrainMSE: {np.round(mean_train_mse, 3)}, TrainMAE: {np.round(mean_train_mae, 3)}, ValMSE: {np.round(mean_validation_mse, 3)}, ValMAE: {np.round(mean_validation_mae, 3)}")

            plt.figure(figsize=(18, 6))
            plt.scatter(all_labels, all_predictions)
            plt.xlabel("Ground Truths")
            plt.ylabel("Predictions")

            plt.show();
        return mean_train_mse, mean_train_mae, mean_validation_mse, mean_validation_mae

# %%
results = []

for model in ["xgboost", "lasso", "svr"]:
    for features in ["book", "chunk", "book_and_averaged_chunk", "chunk_and_copied_book"]:
        for drop_columns_including in [["doc2vec_chunk_embedding"], ["average_sentence_embedding"], ["average_sentence_embedding", "doc2vec_chunk_embedding"], []]:
            for dimensionality_reduction in ["k_best_f_reg_0_10", "ss_pca_0_95", "k_best_mutual_info_0_10", None]:
                try:
                    experiment = Experiment(
                        features=features,
                        drop_columns_including=drop_columns_including,
                        dimensionality_reduction=dimensionality_reduction,
                        model=model,
                        verbose=False
                    )
                    train_mse, train_mae, validation_mse, validation_mae = experiment.run()
                    results.append((model, features, drop_columns_including, dimensionality_reduction, train_mse, train_mae, validation_mse, validation_mae))
                    print(model, features, drop_columns_including, dimensionality_reduction, train_mse, train_mae, validation_mse, validation_mae)
                except Exception as e:
                    print(f"Error in {model}, {features}, {drop_columns_including}, {dimensionality_reduction}")
                    print(e)
# Out:
# xgboost book ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.004395106511642053 0.05092692407694423 0.040185477975627305 0.16258795326899295
# xgboost book ['doc2vec_chunk_embedding'] ss_pca_0_95 0.0011776912780385369 0.02621916002843098 0.040495164287250356 0.16725242747499272
# xgboost book ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.004147081527816702 0.04983046213595589 0.04321931183155643 0.1693928574920156
# xgboost book ['doc2vec_chunk_embedding'] None 0.0007983102992170177 0.021689960666900935 0.03694347215024534 0.15884452520920178
# xgboost book ['average_sentence_embedding'] k_best_f_reg_0_10 0.004395106511642053 0.05092692407694423 0.040185477975627305 0.16258795326899295
# xgboost book ['average_sentence_embedding'] ss_pca_0_95 0.0011776912780385369 0.02621916002843098 0.040495164287250356 0.16725242747499272
# xgboost book ['average_sentence_embedding'] k_best_mutual_info_0_10 0.0040962145676739295 0.049768781270957005 0.04365493234389655 0.17098115083628876
# xgboost book ['average_sentence_embedding'] None 0.0007983102992170177 0.021689960666900935 0.03694347215024534 0.15884452520920178
# xgboost book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.004395106511642053 0.05092692407694423 0.040185477975627305 0.16258795326899295
# xgboost book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.0011776912780385369 0.02621916002843098 0.040495164287250356 0.16725242747499272
# xgboost book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.004233816767847955 0.05052180814637704 0.04194243052117897 0.16806335676121556
# xgboost book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.0007983102992170177 0.021689960666900935 0.03694347215024534 0.15884452520920178
# xgboost book [] k_best_f_reg_0_10 0.004395106511642053 0.05092692407694423 0.040185477975627305 0.16258795326899295
# xgboost book [] ss_pca_0_95 0.0011776912780385369 0.02621916002843098 0.040495164287250356 0.16725242747499272
# xgboost book [] k_best_mutual_info_0_10 0.00411442266096698 0.04967805404433591 0.04410743122083717 0.17201220789921237
# xgboost book [] None 0.0007983102992170177 0.021689960666900935 0.03694347215024534 0.15884452520920178
# xgboost chunk ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.02150244461226919 0.1227322886863816 0.04385214956912718 0.1771004781550045
# xgboost chunk ['doc2vec_chunk_embedding'] ss_pca_0_95 0.02581882475891533 0.1362081863512446 0.044315338489211056 0.18053900251031788
# xgboost chunk ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.02150244461226919 0.1227322886863816 0.04385214956912718 0.1771004781550045
# xgboost chunk ['doc2vec_chunk_embedding'] None 0.02150244461226919 0.1227322886863816 0.04385214956912718 0.1771004781550045
# xgboost chunk ['average_sentence_embedding'] k_best_f_reg_0_10 0.022222957172824048 0.12313220492799988 0.03876203393550594 0.16480931604765775
# xgboost chunk ['average_sentence_embedding'] ss_pca_0_95 0.02473981626099222 0.12991359979483513 0.0393737295422014 0.16673532927974102
# xgboost chunk ['average_sentence_embedding'] k_best_mutual_info_0_10 0.022222957172824048 0.12313220492799988 0.03876203393550594 0.16480931604765775
# xgboost chunk ['average_sentence_embedding'] None 0.022222957172824048 0.12313220492799988 0.03876203393550594 0.16480931604765775
# xgboost chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.036683741279800106 0.1599753013754735 0.04774942814178057 0.1840924268475754
# xgboost chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.03987286218424986 0.16840162918751075 0.049905394910318014 0.18970757517956063
# xgboost chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.036683741279800106 0.1599753013754735 0.04774942814178057 0.1840924268475754
# xgboost chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.036683741279800106 0.1599753013754735 0.04774942814178057 0.1840924268475754
# xgboost chunk [] k_best_f_reg_0_10 0.018693448204811777 0.11378764305948474 0.039292475052607634 0.1678838591364042
# xgboost chunk [] ss_pca_0_95 0.023307780508334177 0.12859520263780175 0.04209837030152077 0.17352514372051916
# xgboost chunk [] k_best_mutual_info_0_10 0.018693448204811777 0.11378764305948474 0.039292475052607634 0.1678838591364042
# xgboost chunk [] None 0.018693448204811777 0.11378764305948474 0.039292475052607634 0.1678838591364042
# xgboost book_and_averaged_chunk ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.0040976572906234006 0.05000391298955702 0.04068578917208111 0.16605450232697155
# xgboost book_and_averaged_chunk ['doc2vec_chunk_embedding'] ss_pca_0_95 0.0008738238056910602 0.02300135775861931 0.039323043444166594 0.16441432464529607
# xgboost book_and_averaged_chunk ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.0038760922576792202 0.04862356479351896 0.04508308144655156 0.17471807296804337
# xgboost book_and_averaged_chunk ['doc2vec_chunk_embedding'] None 0.0003770668097252465 0.014824796771202034 0.03726069814459155 0.15919654098331235
# xgboost book_and_averaged_chunk ['average_sentence_embedding'] k_best_f_reg_0_10 0.004037786788519401 0.04847979552388837 0.03696719612062835 0.15785865469170762
# xgboost book_and_averaged_chunk ['average_sentence_embedding'] ss_pca_0_95 0.000970328000928734 0.023737223332779257 0.038890704911638124 0.16440682788185737
# xgboost book_and_averaged_chunk ['average_sentence_embedding'] k_best_mutual_info_0_10 0.0041326497073693085 0.04985360005748625 0.043391861920395555 0.17154008194567127
# xgboost book_and_averaged_chunk ['average_sentence_embedding'] None 0.0006228793547517508 0.019210312975758495 0.03553353999002438 0.15575743985644092
# xgboost book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.004514136957496333 0.051285949394905016 0.04053803102475316 0.1641929214470046
# xgboost book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.0012564515892822005 0.02707491878438305 0.03985898933242543 0.1654459813468181
# xgboost book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.004163019749679406 0.05013646376245788 0.042619805435450575 0.17002805255464895
# xgboost book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.0007687960029318421 0.021340307016457002 0.035993778323687775 0.15569820156551273
# xgboost book_and_averaged_chunk [] k_best_f_reg_0_10 0.003537854665080211 0.04590402698001659 0.03617722230368561 0.15630184001312025
# xgboost book_and_averaged_chunk [] ss_pca_0_95 0.0007188591312395079 0.02071531245262436 0.03912060576418368 0.1656293702381107
# xgboost book_and_averaged_chunk [] k_best_mutual_info_0_10 0.0037503776358426494 0.04770984648143545 0.04547324568599676 0.17433469556513165
# xgboost book_and_averaged_chunk [] None 0.00034253243866824175 0.014185504195785797 0.03587939601911001 0.1561994256550899
# xgboost chunk_and_copied_book ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.0025533459744033716 0.03583333707729959 0.03814361380197414 0.1602144309004054
# xgboost chunk_and_copied_book ['doc2vec_chunk_embedding'] ss_pca_0_95 0.015035789335803023 0.10087702195652584 0.04138733533044659 0.17096756133355306
# xgboost chunk_and_copied_book ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.0024034493830057246 0.03465508518027566 0.038269426991722796 0.16087990431837473
# xgboost chunk_and_copied_book ['doc2vec_chunk_embedding'] None 0.002475369221110566 0.03516523703011688 0.03854780718790555 0.16067967920931767
# xgboost chunk_and_copied_book ['average_sentence_embedding'] k_best_f_reg_0_10 0.002476935252984599 0.03530169929688107 0.0383120772468431 0.16059152530780704
# xgboost chunk_and_copied_book ['average_sentence_embedding'] ss_pca_0_95 0.0075719257803575106 0.06729035529316635 0.03926307282982398 0.16433357022008627
# xgboost chunk_and_copied_book ['average_sentence_embedding'] k_best_mutual_info_0_10 0.002476935252984599 0.03530169929688107 0.0383120772468431 0.16059152530780704
# xgboost chunk_and_copied_book ['average_sentence_embedding'] None 0.002476935252984599 0.03530169929688107 0.0383120772468431 0.16059152530780704
# xgboost chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.0024583196165833695 0.03509264440133396 0.03897736558918146 0.16207895309677173
# xgboost chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.004482793275751634 0.049384577031932414 0.04176112297048287 0.16789881430923614
# xgboost chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.0024583196165833695 0.03509264440133396 0.03897736558918146 0.16207895309677173
# xgboost chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.0024583196165833695 0.03509264440133396 0.03897736558918146 0.16207895309677173
# xgboost chunk_and_copied_book [] k_best_f_reg_0_10 0.002649411573919099 0.03655064165795964 0.03864627318922971 0.1614513541671529
# xgboost chunk_and_copied_book [] ss_pca_0_95 0.014907325633593756 0.1003449887710087 0.0404012016844716 0.16795442940136698
# xgboost chunk_and_copied_book [] k_best_mutual_info_0_10 0.0024168209225177255 0.03479286662478129 0.03822492547719074 0.16067962566990285
# xgboost chunk_and_copied_book [] None 0.0024639740275980595 0.03510234757435796 0.03852391084142039 0.16149381087448172
# lasso book ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.04982222534337351 0.19184580878664576 0.05190611264591002 0.196605218182724
# lasso book ['doc2vec_chunk_embedding'] ss_pca_0_95 0.052288562232815375 0.19863761567505872 0.05242214291051835 0.19900419149846788
# lasso book ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.04930647210662376 0.19117062201140894 0.0517809073174129 0.19648845589208347
# lasso book ['doc2vec_chunk_embedding'] None 0.044919578834384674 0.18150831675034135 0.04967974483867274 0.1910680728239779
# lasso book ['average_sentence_embedding'] k_best_f_reg_0_10 0.04982222534337351 0.19184580878664576 0.05190611264591002 0.196605218182724
# lasso book ['average_sentence_embedding'] ss_pca_0_95 0.052288562232815375 0.19863761567505872 0.05242214291051835 0.19900419149846788
# lasso book ['average_sentence_embedding'] k_best_mutual_info_0_10 0.04915717036848476 0.19083106600308922 0.051362050711025474 0.19561673616104105
# lasso book ['average_sentence_embedding'] None 0.044919578834384674 0.18150831675034135 0.04967974483867274 0.1910680728239779
# lasso book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.04982222534337351 0.19184580878664576 0.05190611264591002 0.196605218182724
# lasso book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.052288562232815375 0.19863761567505872 0.05242214291051835 0.19900419149846788
# lasso book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.04920846758928701 0.19090615548804538 0.05131360846726056 0.19492959873233112
# lasso book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.044919578834384674 0.18150831675034135 0.04967974483867274 0.1910680728239779
# lasso book [] k_best_f_reg_0_10 0.04982222534337351 0.19184580878664576 0.05190611264591002 0.196605218182724
# lasso book [] ss_pca_0_95 0.052288562232815375 0.19863761567505872 0.05242214291051835 0.19900419149846788
# lasso book [] k_best_mutual_info_0_10 0.04933768193127641 0.1912992041847478 0.05136908756468259 0.19524988275941868
# lasso book [] None 0.044919578834384674 0.18150831675034135 0.04967974483867274 0.1910680728239779
# lasso chunk ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk ['doc2vec_chunk_embedding'] ss_pca_0_95 0.0528496278591122 0.1995759717632932 0.05303440043751308 0.2000230031932908
# lasso chunk ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk ['doc2vec_chunk_embedding'] None 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk ['average_sentence_embedding'] k_best_f_reg_0_10 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk ['average_sentence_embedding'] ss_pca_0_95 0.0528496278591122 0.1995759717632932 0.05303440043751308 0.2000230031932908
# lasso chunk ['average_sentence_embedding'] k_best_mutual_info_0_10 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk ['average_sentence_embedding'] None 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.0528496278591122 0.1995759717632932 0.05303440043751308 0.2000230031932908
# lasso chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk [] k_best_f_reg_0_10 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk [] ss_pca_0_95 0.0528496278591122 0.1995759717632932 0.05303440043751308 0.2000230031932908
# lasso chunk [] k_best_mutual_info_0_10 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso chunk [] None 0.05142011477081868 0.196403098790993 0.052010023529795925 0.19760104116726088
# lasso book_and_averaged_chunk ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.049136514031314645 0.1894600694333623 0.05150626869242823 0.19415455686719935
# lasso book_and_averaged_chunk ['doc2vec_chunk_embedding'] ss_pca_0_95 0.052288562232815375 0.19863761567505872 0.05242214291051835 0.19900419149846788
# lasso book_and_averaged_chunk ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.04998818103022503 0.1928245337464097 0.05164453517691196 0.19594244222602503
# lasso book_and_averaged_chunk ['doc2vec_chunk_embedding'] None 0.04342120211616355 0.1768226981663153 0.047675536508997064 0.18460609625635999
# lasso book_and_averaged_chunk ['average_sentence_embedding'] k_best_f_reg_0_10 0.04880912010417264 0.18856718554665125 0.050960304410258214 0.19254122268863802
# lasso book_and_averaged_chunk ['average_sentence_embedding'] ss_pca_0_95 0.052288562232815375 0.19863761567505872 0.05242214291051835 0.19900419149846788
# lasso book_and_averaged_chunk ['average_sentence_embedding'] k_best_mutual_info_0_10 0.049519883320061554 0.1916420840506517 0.05171149771716728 0.19622144046025708
# lasso book_and_averaged_chunk ['average_sentence_embedding'] None 0.04342120211616355 0.1768226981663153 0.047675536508997064 0.18460609625635999
# lasso book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.048103644154043806 0.1868124916410818 0.05025534013923769 0.1913403199539916
# lasso book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.052288562232815375 0.19863761567505872 0.05242214291051835 0.19900419149846788
# lasso book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.049422162833963085 0.19149216803897698 0.05165345833462374 0.19624262028834455
# lasso book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.04342120211616355 0.1768226981663153 0.047675536508997064 0.18460609625635999
# lasso book_and_averaged_chunk [] k_best_f_reg_0_10 0.04963581000309677 0.19089188648035013 0.05294051135816212 0.19768433047359998
# lasso book_and_averaged_chunk [] ss_pca_0_95 0.052288562232815375 0.19863761567505872 0.05242214291051835 0.19900419149846788
# lasso book_and_averaged_chunk [] k_best_mutual_info_0_10 0.05025215188231417 0.19343307808368917 0.05236246907814859 0.1975239556639369
# lasso book_and_averaged_chunk [] None 0.04342120211616355 0.1768226981663153 0.047675536508997064 0.18460609625635999
# lasso chunk_and_copied_book ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.049266137182025 0.18925534708770178 0.05357294969873784 0.19873564865174614
# lasso chunk_and_copied_book ['doc2vec_chunk_embedding'] ss_pca_0_95 0.0528496278591122 0.1995759717632932 0.05303440043751308 0.2000230031932908
# lasso chunk_and_copied_book ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.04927321698542199 0.1892678622986396 0.053602162643975826 0.19881491135217183
# lasso chunk_and_copied_book ['doc2vec_chunk_embedding'] None 0.04927321698542199 0.18926786229863962 0.05360216264397581 0.19881491135217183
# lasso chunk_and_copied_book ['average_sentence_embedding'] k_best_f_reg_0_10 0.04927321698542199 0.1892678622986396 0.053602162643975826 0.19881491135217183
# lasso chunk_and_copied_book ['average_sentence_embedding'] ss_pca_0_95 0.0528496278591122 0.1995759717632932 0.05303440043751308 0.2000230031932908
# lasso chunk_and_copied_book ['average_sentence_embedding'] k_best_mutual_info_0_10 0.04927321698542199 0.1892678622986396 0.053602162643975826 0.19881491135217183
# lasso chunk_and_copied_book ['average_sentence_embedding'] None 0.04927321698542199 0.1892678622986396 0.053602162643975826 0.19881491135217183
# lasso chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.04927321698542199 0.18926786229863962 0.05360216264397581 0.19881491135217183
# lasso chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.0528496278591122 0.1995759717632932 0.05303440043751308 0.2000230031932908
# lasso chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.04927321698542199 0.18926786229863962 0.05360216264397581 0.19881491135217183
# lasso chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.04927321698542199 0.18926786229863962 0.05360216264397581 0.19881491135217183
# lasso chunk_and_copied_book [] k_best_f_reg_0_10 0.04928463478389988 0.18927971250522835 0.05354808117780564 0.19863851742579566
# lasso chunk_and_copied_book [] ss_pca_0_95 0.0528496278591122 0.1995759717632932 0.05303440043751308 0.2000230031932908
# lasso chunk_and_copied_book [] k_best_mutual_info_0_10 0.04927321698542199 0.1892678622986396 0.053602162643975826 0.19881491135217183
# lasso chunk_and_copied_book [] None 0.04927321698542199 0.1892678622986396 0.053602162643975826 0.19881491135217183
# svr book ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.04461808748170161 0.176108601503228 0.05322960365327052 0.19438744165634378
# svr book ['doc2vec_chunk_embedding'] ss_pca_0_95 0.007659791783954054 0.08228123872353485 0.035916841916364975 0.15627015311698564
# svr book ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.02849315228831444 0.13567124531138172 0.054916353135059916 0.19171672289302907
# svr book ['doc2vec_chunk_embedding'] None 0.010367215490363114 0.08997508919750705 0.04235044950434685 0.16876327726423324
# svr book ['average_sentence_embedding'] k_best_f_reg_0_10 0.04461808748170161 0.176108601503228 0.05322960365327052 0.19438744165634378
# svr book ['average_sentence_embedding'] ss_pca_0_95 0.007659791783954054 0.08228123872353485 0.035916841916364975 0.15627015311698564
# svr book ['average_sentence_embedding'] k_best_mutual_info_0_10 0.026714881463757684 0.13189296975529285 0.05376520014336137 0.18935718334859536
# svr book ['average_sentence_embedding'] None 0.010367215490363114 0.08997508919750705 0.04235044950434685 0.16876327726423324
# svr book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.04461808748170161 0.176108601503228 0.05322960365327052 0.19438744165634378
# svr book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.007659791783954054 0.08228123872353485 0.035916841916364975 0.15627015311698564
# svr book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.027387918977179366 0.1327455106104112 0.053794153804045064 0.1896927087478302
# svr book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.010367215490363114 0.08997508919750705 0.04235044950434685 0.16876327726423324
# svr book [] k_best_f_reg_0_10 0.04461808748170161 0.176108601503228 0.05322960365327052 0.19438744165634378
# svr book [] ss_pca_0_95 0.007659791783954054 0.08228123872353485 0.035916841916364975 0.15627015311698564
# svr book [] k_best_mutual_info_0_10 0.027110681858004103 0.13217829466130623 0.05447646882425945 0.19157218491376213
# svr book [] None 0.010367215490363114 0.08997508919750705 0.04235044950434685 0.16876327726423324
# svr chunk ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.049347968777009685 0.1893307622500912 0.050336750899294014 0.1916926664720794
# svr chunk ['doc2vec_chunk_embedding'] ss_pca_0_95 0.005555627105736861 0.06771378568590207 0.03891644420761446 0.16625727418694697
# svr chunk ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.049347968777009685 0.1893307622500912 0.050336750899294014 0.1916926664720794
# svr chunk ['doc2vec_chunk_embedding'] None 0.049347968777009685 0.1893307622500912 0.050336750899294014 0.1916926664720794
# svr chunk ['average_sentence_embedding'] k_best_f_reg_0_10 0.04934438898465328 0.18933298573409924 0.05034328422314638 0.19170804085694346
# svr chunk ['average_sentence_embedding'] ss_pca_0_95 0.005143162837108839 0.06459481117601654 0.03243065476489043 0.14835489751913225
# svr chunk ['average_sentence_embedding'] k_best_mutual_info_0_10 0.04934438898465328 0.18933298573409924 0.05034328422314638 0.19170804085694346
# svr chunk ['average_sentence_embedding'] None 0.04934438898465328 0.18933298573409924 0.05034328422314638 0.19170804085694346
# svr chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.04933863319327353 0.189332214129348 0.05034871551123592 0.19174396940787974
# svr chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.033252479807907784 0.14743074281970384 0.046518987326874664 0.17798299618774813
# svr chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.04933863319327353 0.189332214129348 0.05034871551123592 0.19174396940787974
# svr chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.04933863319327353 0.189332214129348 0.05034871551123592 0.19174396940787974
# svr chunk [] k_best_f_reg_0_10 0.04934532142653281 0.18933066318185482 0.05034055972726077 0.1916989600768598
# svr chunk [] ss_pca_0_95 0.005640375460407676 0.06906871296426753 0.035505756702121624 0.1588467380575425
# svr chunk [] k_best_mutual_info_0_10 0.04934532142653281 0.18933066318185482 0.05034055972726077 0.1916989600768598
# svr chunk [] None 0.04934532142653281 0.18933066318185482 0.05034055972726077 0.1916989600768598
# svr book_and_averaged_chunk ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.04820907710592063 0.18640539411066778 0.048970184074053166 0.18837390788664554
# svr book_and_averaged_chunk ['doc2vec_chunk_embedding'] ss_pca_0_95 0.007941578704401235 0.08447197617029523 0.03491797879116861 0.1562061656946918
# svr book_and_averaged_chunk ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.03607078016392179 0.1547280883731741 0.05704049151513495 0.1969677943731701
# svr book_and_averaged_chunk ['doc2vec_chunk_embedding'] None 0.047497750953138594 0.18492946375215233 0.04843621782512168 0.18732906751654105
# svr book_and_averaged_chunk ['average_sentence_embedding'] k_best_f_reg_0_10 0.04818861214131204 0.18636303611959565 0.04895039514253374 0.18835351913536047
# svr book_and_averaged_chunk ['average_sentence_embedding'] ss_pca_0_95 0.007656936604754791 0.08237444233073228 0.03340628185667521 0.15073501334355627
# svr book_and_averaged_chunk ['average_sentence_embedding'] k_best_mutual_info_0_10 0.030729079006319177 0.1415893749410528 0.056608882383728756 0.19520747488604537
# svr book_and_averaged_chunk ['average_sentence_embedding'] None 0.04749668223005403 0.18492152239131193 0.04842993173526523 0.18730232952364545
# svr book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.048113771065838876 0.1862301623398154 0.048896425751965664 0.1882926814478329
# svr book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.007735812712813361 0.08259958915503951 0.03558143185154381 0.15522803174767702
# svr book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.030722646084349537 0.14146869560804304 0.05568422756632228 0.1942371764074312
# svr book_and_averaged_chunk ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.04749694968949098 0.18491962468971973 0.04844422031097721 0.18733980957967036
# svr book_and_averaged_chunk [] k_best_f_reg_0_10 0.04663459370103118 0.1829228849472512 0.04863648258715643 0.18726967913963075
# svr book_and_averaged_chunk [] ss_pca_0_95 0.007899227381140664 0.08421214399198342 0.034252870736344185 0.15462065896215896
# svr book_and_averaged_chunk [] k_best_mutual_info_0_10 0.034994985965253474 0.15215586397220254 0.05610946767646352 0.1945544845983054
# svr book_and_averaged_chunk [] None 0.047498501241027336 0.1849250877195176 0.048440781767798494 0.1873355455575164
# svr chunk_and_copied_book ['doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.04744852984935617 0.18403653150026802 0.05087337499497664 0.1916884763132547
# svr chunk_and_copied_book ['doc2vec_chunk_embedding'] ss_pca_0_95 0.006373685459671268 0.07512277134534298 0.034660256006429746 0.155499582129009
# svr chunk_and_copied_book ['doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.04739077418810912 0.1838406412208303 0.05082307993268438 0.19157665280682043
# svr chunk_and_copied_book ['doc2vec_chunk_embedding'] None 0.0473879165471573 0.18383146809349027 0.050816428581617855 0.1915642267518575
# svr chunk_and_copied_book ['average_sentence_embedding'] k_best_f_reg_0_10 0.04738440977105129 0.1838301222856718 0.050817696669277636 0.19156723211372167
# svr chunk_and_copied_book ['average_sentence_embedding'] ss_pca_0_95 0.007126081484133797 0.07946943421722294 0.03504384326032629 0.15574806531401877
# svr chunk_and_copied_book ['average_sentence_embedding'] k_best_mutual_info_0_10 0.04738440977105129 0.1838301222856718 0.050817696669277636 0.19156723211372167
# svr chunk_and_copied_book ['average_sentence_embedding'] None 0.04738440977105129 0.1838301222856718 0.050817696669277636 0.19156723211372167
# svr chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_f_reg_0_10 0.04738938683231725 0.1838370169378885 0.05082095277565356 0.19156871704177036
# svr chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] ss_pca_0_95 0.0073731709131250305 0.08090271130792388 0.036053847342540746 0.1580019886331534
# svr chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] k_best_mutual_info_0_10 0.04738938683231725 0.1838370169378885 0.05082095277565356 0.19156871704177036
# svr chunk_and_copied_book ['average_sentence_embedding', 'doc2vec_chunk_embedding'] None 0.04738938683231725 0.1838370169378885 0.05082095277565356 0.19156871704177036
# svr chunk_and_copied_book [] k_best_f_reg_0_10 0.04739909309039983 0.18379084473496327 0.050898551187770494 0.19184131444480265
# svr chunk_and_copied_book [] ss_pca_0_95 0.006450177214733277 0.07568743330478546 0.03421412476036296 0.15459322514406965
# svr chunk_and_copied_book [] k_best_mutual_info_0_10 0.04738578904453949 0.18383359019575765 0.05081600222061207 0.1915669526722186
# svr chunk_and_copied_book [] None 0.04738790565148597 0.18383868920975113 0.050813915041373524 0.19155165081185907

# %% [markdown]
# # Validation MAE medians

# %%
results_df = pd.DataFrame(results, columns=["model", "features", "drop_columns_including", "dimensionality_reduction", "train_mse", "train_mae", "validation_mse", "validation_mae"])
results_df["drop_columns_including"] = results_df["drop_columns_including"].apply(str)

# %%
results_df.groupby("model").agg({"validation_mae": "median"})
# Out:
#          validation_mae
# model
# lasso          0.197601
# svr            0.191566
# xgboost        0.164809

# %%
results_df.groupby("features").agg({"validation_mae": "median"})
# Out:
#                          validation_mae
# features
# book                           0.180685
# book_and_averaged_chunk        0.185938
# chunk                          0.191699
# chunk_and_copied_book          0.191567

# %%
results_df.groupby("drop_columns_including").agg({"validation_mae": "median"})
# Out:
#                                                     validation_mae
# drop_columns_including
# ['average_sentence_embedding', 'doc2vec_chunk_e...        0.189700
# ['average_sentence_embedding']                            0.188855
# ['doc2vec_chunk_embedding']                               0.189721
# []                                                        0.189202

# %%
results_df.groupby("dimensionality_reduction").agg({"validation_mae": "median"})
# Out:
#                           validation_mae
# dimensionality_reduction
# k_best_f_reg_0_10               0.191691
# k_best_mutual_info_0_10         0.191696
# ss_pca_0_95                     0.167252

# %% [markdown]
# # Best result

# %%
results_df[results_df.validation_mae == results_df.validation_mae.min()]
# Out:
#     model features          drop_columns_including dimensionality_reduction  \
# 149   svr    chunk  ['average_sentence_embedding']              ss_pca_0_95
#
#      train_mse  train_mae  validation_mse  validation_mae
# 149   0.005143   0.064595        0.032431        0.148355

# %%
results_df.to_csv("../data/results/model_features_drop_columns_including_dimensionality_reduction_ger.csv", index=False)
