# %%
'''
Recursive Feature Elimination. This is the best result(in terms of MAE and for both languages) we have right now.
'''

# %%
random_seed = 42
import numpy as np; np.random.seed(random_seed)
import xgboost
from sklearn.metrics import mean_absolute_error
import pandas as pd
from copy import deepcopy


class HyperParameterOptimizer(object):
    def __init__(self):
        self.model = None
        self.feature_importances_ = None
    
    def fit(self, _train_X, _train_y):
        print(f"Current shape of feature matrix:", _train_X.shape)
        num_boost_round = 99999

        def feval(preds, train_data):
            labels = train_data.get_label()
            return 'mae', mean_absolute_error(labels, preds)
        
        all_results = []
        for max_depth in [4]: # [5, 10, 15, 20, 25]
            for learning_rate in [0.03]:
                for colsample_bytree in [0.33]:
                    for min_child_weight in [6]: # 3, 6, 8, 12
                        train_X = deepcopy(_train_X)
                        train_y = deepcopy(_train_y)
                        dtrain = xgboost.DMatrix(train_X, label=train_y)
                        params = {"max_depth": max_depth, "learning_rate": learning_rate, "colsample_bytree": colsample_bytree, "min_child_weight": min_child_weight, "n_jobs": -1}
                        cv_results = xgboost.cv(
                            params,
                            dtrain,
                            num_boost_round=num_boost_round,
                            seed=random_seed,
                            nfold=10,
                            feval=feval,
                            early_stopping_rounds=20,
                            verbose_eval=False
                        )
                        print(train_X.shape[1], max_depth, learning_rate, colsample_bytree, min_child_weight, np.round(float(cv_results["test-mae-mean"].iloc[len(cv_results["test-mae-mean"])-1]), 4))
                        all_results.append((max_depth, learning_rate, colsample_bytree, min_child_weight, cv_results))
        all_results_df = pd.DataFrame(all_results, columns=["max_depth", "learning_rate", "colsample_bytree", "min_child_weight", "cv_results"])
        all_results_df["best_validation_f1"] = all_results_df["cv_results"].apply(lambda x: x.iloc[len(x)-1]["test-mae-mean"])
        all_results_df = all_results_df.sort_values(by="best_validation_f1", ascending=False).reset_index(drop=True)
        best_parameters = all_results_df.iloc[0]
        best_max_depth = int(best_parameters["max_depth"])
        best_learning_rate = float(best_parameters["learning_rate"])
        best_colsample_bytree = float(best_parameters["colsample_bytree"])
        best_min_child_weight = float(best_parameters["min_child_weight"])
        best_validation_f1 = float(best_parameters["best_validation_f1"])
        best_num_boost_round = int(len(best_parameters["cv_results"]))
        
        print("Current best max_depth:", best_max_depth)
        print("Current best learning_rate:", best_learning_rate)
        print("Current best colsample_bytree:", best_colsample_bytree)
        print("Current best min_child_weight:", best_min_child_weight)
        print("Current best num_boost_round:", best_num_boost_round)
        params = {"max_depth": best_max_depth, "learning_rate": best_learning_rate, "colsample_bytree": best_colsample_bytree, "min_child_weight": best_min_child_weight, "n_jobs": -1}
        
        train_X = deepcopy(_train_X)
        train_y = deepcopy(_train_y)
        dtrain = xgboost.DMatrix(train_X, label=train_y)
        model = xgboost.train(params,
                              dtrain,
                              num_boost_round=best_num_boost_round,
                              verbose_eval=False)
        feature_importances = model.get_score(importance_type='gain')
        feature_importances_list = []
        for i in range(train_X.shape[1]):
            current_key = f'f{i}'
            if current_key in feature_importances:
                feature_importances_list.append(feature_importances[current_key])
            else:
                feature_importances_list.append(0.0)
        print(f"Current best validation f1 score is {np.round(best_validation_f1, 4)}")
        print("############################")
        self.model = model
        self.feature_importances_ = np.array(feature_importances_list)
        return self
    
    def predict(self, X):
        return self.model.predict(xgboost.DMatrix(X))

    def predict_proba(self, X):
        return self.predict(X)
    
    def decision_function(self, X):
        return self.predict(X)
    
    def transform(self, X):
        return self.predict(X)

    def score(self, X=None, y=None):
        return 0.0

    def get_params(self, deep=True):
        return {}

    def set_params(self, **params):
        return self

    def _get_tags(self):
        return {"allow_nan": True}

# %%
from sklearn.feature_selection import RFE
import sys
sys.path.insert(0, "../src/")
import numpy as np
import pandas as pd
from utils import read_labels

labels_dir = "../data/labels/"
lang = "eng"
labels = read_labels(labels_dir)

extracted_features_dir = "../data/extracted_features/"

book_and_averaged_chunk_df = pd.read_csv(f"{extracted_features_dir}/{lang}/book_and_averaged_chunk_df.csv")

train_X = book_and_averaged_chunk_df.drop(columns=["book_name"])
train_X = train_X[[column for column in train_X.columns if "average_sentence_embedding" not in column]].values
train_y = book_and_averaged_chunk_df["book_name"].apply(lambda x: labels[x]).values

hpo = HyperParameterOptimizer()
rfe = RFE(hpo, step=10, n_features_to_select=10, verbose=0)
rfe.fit(train_X, train_y)
# Out:
# Current shape of feature matrix: (599, 535)
# 535 4 0.03 0.33 6 0.1734
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 724
# Current best validation f1 score is 0.1734
# ############################
# Current shape of feature matrix: (599, 525)
# 525 4 0.03 0.33 6 0.1716
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1148
# Current best validation f1 score is 0.1716
# ############################
# Current shape of feature matrix: (599, 515)
# 515 4 0.03 0.33 6 0.1704
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 891
# Current best validation f1 score is 0.1704
# ############################
# Current shape of feature matrix: (599, 505)
# 505 4 0.03 0.33 6 0.1729
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 647
# Current best validation f1 score is 0.1729
# ############################
# Current shape of feature matrix: (599, 495)
# 495 4 0.03 0.33 6 0.1715
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 891
# Current best validation f1 score is 0.1715
# ############################
# Current shape of feature matrix: (599, 485)
# 485 4 0.03 0.33 6 0.1724
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 876
# Current best validation f1 score is 0.1724
# ############################
# Current shape of feature matrix: (599, 475)
# 475 4 0.03 0.33 6 0.1711
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1000
# Current best validation f1 score is 0.1711
# ############################
# Current shape of feature matrix: (599, 465)
# 465 4 0.03 0.33 6 0.1707
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 717
# Current best validation f1 score is 0.1707
# ############################
# Current shape of feature matrix: (599, 455)
# 455 4 0.03 0.33 6 0.1678
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 816
# Current best validation f1 score is 0.1678
# ############################
# Current shape of feature matrix: (599, 445)
# 445 4 0.03 0.33 6 0.1693
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 608
# Current best validation f1 score is 0.1693
# ############################
# Current shape of feature matrix: (599, 435)
# 435 4 0.03 0.33 6 0.1706
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1387
# Current best validation f1 score is 0.1706
# ############################
# Current shape of feature matrix: (599, 425)
# 425 4 0.03 0.33 6 0.1683
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1123
# Current best validation f1 score is 0.1683
# ############################
# Current shape of feature matrix: (599, 415)
# 415 4 0.03 0.33 6 0.1691
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 854
# Current best validation f1 score is 0.1691
# ############################
# Current shape of feature matrix: (599, 405)
# 405 4 0.03 0.33 6 0.168
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 951
# Current best validation f1 score is 0.168
# ############################
# Current shape of feature matrix: (599, 395)
# 395 4 0.03 0.33 6 0.1671
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 850
# Current best validation f1 score is 0.1671
# ############################
# Current shape of feature matrix: (599, 385)
# 385 4 0.03 0.33 6 0.1669
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 899
# Current best validation f1 score is 0.1669
# ############################
# Current shape of feature matrix: (599, 375)
# 375 4 0.03 0.33 6 0.1677
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 959
# Current best validation f1 score is 0.1677
# ############################
# Current shape of feature matrix: (599, 365)
# 365 4 0.03 0.33 6 0.1663
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 818
# Current best validation f1 score is 0.1663
# ############################
# Current shape of feature matrix: (599, 355)
# 355 4 0.03 0.33 6 0.1679
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 653
# Current best validation f1 score is 0.1679
# ############################
# Current shape of feature matrix: (599, 345)
# 345 4 0.03 0.33 6 0.1667
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 912
# Current best validation f1 score is 0.1667
# ############################
# Current shape of feature matrix: (599, 335)
# 335 4 0.03 0.33 6 0.1657
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 846
# Current best validation f1 score is 0.1657
# ############################
# Current shape of feature matrix: (599, 325)
# 325 4 0.03 0.33 6 0.1654
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 895
# Current best validation f1 score is 0.1654
# ############################
# Current shape of feature matrix: (599, 315)
# 315 4 0.03 0.33 6 0.1643
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 923
# Current best validation f1 score is 0.1643
# ############################
# Current shape of feature matrix: (599, 305)
# 305 4 0.03 0.33 6 0.1634
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1035
# Current best validation f1 score is 0.1634
# ############################
# Current shape of feature matrix: (599, 295)
# 295 4 0.03 0.33 6 0.1641
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 768
# Current best validation f1 score is 0.1641
# ############################
# Current shape of feature matrix: (599, 285)
# 285 4 0.03 0.33 6 0.1658
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 691
# Current best validation f1 score is 0.1658
# ############################
# Current shape of feature matrix: (599, 275)
# 275 4 0.03 0.33 6 0.1634
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 1020
# Current best validation f1 score is 0.1634
# ############################
# Current shape of feature matrix: (599, 265)
# 265 4 0.03 0.33 6 0.163
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 744
# Current best validation f1 score is 0.163
# ############################
# Current shape of feature matrix: (599, 255)
# 255 4 0.03 0.33 6 0.1627
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 708
# Current best validation f1 score is 0.1627
# ############################
# Current shape of feature matrix: (599, 245)
# 245 4 0.03 0.33 6 0.1622
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 698
# Current best validation f1 score is 0.1622
# ############################
# Current shape of feature matrix: (599, 235)
# 235 4 0.03 0.33 6 0.1633
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 725
# Current best validation f1 score is 0.1633
# ############################
# Current shape of feature matrix: (599, 225)
# 225 4 0.03 0.33 6 0.1618
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 723
# Current best validation f1 score is 0.1618
# ############################
# Current shape of feature matrix: (599, 215)
# 215 4 0.03 0.33 6 0.1617
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 881
# Current best validation f1 score is 0.1617
# ############################
# Current shape of feature matrix: (599, 205)
# 205 4 0.03 0.33 6 0.162
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 641
# Current best validation f1 score is 0.162
# ############################
# Current shape of feature matrix: (599, 195)
# 195 4 0.03 0.33 6 0.1612
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 730
# Current best validation f1 score is 0.1612
# ############################
# Current shape of feature matrix: (599, 185)
# 185 4 0.03 0.33 6 0.1629
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 939
# Current best validation f1 score is 0.1629
# ############################
# Current shape of feature matrix: (599, 175)
# 175 4 0.03 0.33 6 0.1602
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 842
# Current best validation f1 score is 0.1602
# ############################
# Current shape of feature matrix: (599, 165)
# 165 4 0.03 0.33 6 0.163
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 666
# Current best validation f1 score is 0.163
# ############################
# Current shape of feature matrix: (599, 155)
# 155 4 0.03 0.33 6 0.1613
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 804
# Current best validation f1 score is 0.1613
# ############################
# Current shape of feature matrix: (599, 145)
# 145 4 0.03 0.33 6 0.1611
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 664
# Current best validation f1 score is 0.1611
# ############################
# Current shape of feature matrix: (599, 135)
# 135 4 0.03 0.33 6 0.1581
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 728
# Current best validation f1 score is 0.1581
# ############################
# Current shape of feature matrix: (599, 125)
# 125 4 0.03 0.33 6 0.1606
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 752
# Current best validation f1 score is 0.1606
# ############################
# Current shape of feature matrix: (599, 115)
# 115 4 0.03 0.33 6 0.1615
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 575
# Current best validation f1 score is 0.1615
# ############################
# Current shape of feature matrix: (599, 105)
# 105 4 0.03 0.33 6 0.1581
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 757
# Current best validation f1 score is 0.1581
# ############################
# Current shape of feature matrix: (599, 95)
# 95 4 0.03 0.33 6 0.157
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 666
# Current best validation f1 score is 0.157
# ############################
# Current shape of feature matrix: (599, 85)
# 85 4 0.03 0.33 6 0.1574
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 602
# Current best validation f1 score is 0.1574
# ############################
# Current shape of feature matrix: (599, 75)
# 75 4 0.03 0.33 6 0.1572
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 466
# Current best validation f1 score is 0.1572
# ############################
# Current shape of feature matrix: (599, 65)
# 65 4 0.03 0.33 6 0.1569
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 551
# Current best validation f1 score is 0.1569
# ############################
# Current shape of feature matrix: (599, 55)
# 55 4 0.03 0.33 6 0.1593
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 398
# Current best validation f1 score is 0.1593
# ############################
# Current shape of feature matrix: (599, 45)
# 45 4 0.03 0.33 6 0.1577
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 353
# Current best validation f1 score is 0.1577
# ############################
# Current shape of feature matrix: (599, 35)
# 35 4 0.03 0.33 6 0.1666
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 311
# Current best validation f1 score is 0.1666
# ############################
# Current shape of feature matrix: (599, 25)
# 25 4 0.03 0.33 6 0.1705
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 235
# Current best validation f1 score is 0.1705
# ############################
# Current shape of feature matrix: (599, 15)
# 15 4 0.03 0.33 6 0.1811
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 205
# Current best validation f1 score is 0.1811
# ############################
# Current shape of feature matrix: (599, 10)
# 10 4 0.03 0.33 6 0.1851
# Current best max_depth: 4
# Current best learning_rate: 0.03
# Current best colsample_bytree: 0.33
# Current best min_child_weight: 6.0
# Current best num_boost_round: 195
# Current best validation f1 score is 0.1851
# ############################
# RFE(estimator=<__main__.HyperParameterOptimizer object at 0x1127f0550>,
#     n_features_to_select=10, step=10)

# %%
num_boost_round = 551

# %%
book_and_averaged_chunk_df = pd.read_csv(f"{extracted_features_dir}/{lang}/book_and_averaged_chunk_df.csv")
book_and_averaged_chunk_df = book_and_averaged_chunk_df.drop(columns=["book_name"])
book_and_averaged_chunk_df = book_and_averaged_chunk_df[[column for column in book_and_averaged_chunk_df.columns if "average_sentence_embedding" not in column]]
best_features = book_and_averaged_chunk_df.columns[np.argwhere((rfe.ranking_ <= 7) == True).T[0]].tolist()
print(len(best_features))
print(best_features)
# Out:
# 65
# ['50_most_common_1gram_stopword_True_to', '50_most_common_1gram_stopword_True_that', '50_most_common_1gram_stopword_True_as', '50_most_common_1gram_stopword_True_but', '50_most_common_1gram_stopword_True_on', '50_most_common_1gram_stopword_True_said', '50_most_common_2gram_stopword_True_<BOS> but', '50_most_common_2gram_stopword_True_<BOS> it', '50_most_common_2gram_stopword_True_with a', '50_most_common_2gram_stopword_True_that he', '50_most_common_3gram_stopword_True_<BOS> <BOS> it', '50_most_common_3gram_stopword_True_<BOS> <BOS> oh', '50_most_common_3gram_stopword_True_<BOS> <BOS> well', '50_most_common_3gram_stopword_True_<BOS> <BOS> yes', '50_most_common_3gram_stopword_True_<BOS> <BOS> why', '50_most_common_3gram_stopword_True_<BOS> <BOS> her', '50_most_common_1gram_stopword_False_said', '50_most_common_1gram_stopword_False_house', '50_most_common_1gram_stopword_False_face', '50_most_common_2gram_stopword_False_<BOS> oh', '50_most_common_2gram_stopword_False_<BOS> yes', '50_most_common_2gram_stopword_False_said <EOS>', '50_most_common_2gram_stopword_False_said mr', '50_most_common_2gram_stopword_False_<BOS> let', '50_most_common_2gram_stopword_False_o clock', '50_most_common_2gram_stopword_False_door <EOS>', '50_most_common_2gram_stopword_False_face <EOS>', '50_most_common_2gram_stopword_False_<BOS> o', '50_most_common_3gram_stopword_False_<BOS> <BOS> oh', '50_most_common_3gram_stopword_False_<BOS> <BOS> yes', '50_most_common_3gram_stopword_False_day <EOS> <EOS>', '50_most_common_3gram_stopword_False_heart <EOS> <EOS>', '50_most_common_3gram_stopword_False_face <EOS> <EOS>', '50_most_common_3gram_stopword_False_<BOS> <BOS> o', '50_most_common_3gram_stopword_False_<BOS> <BOS> lady', '50_most_common_3gram_stopword_False_place <EOS> <EOS>', '50_most_common_3gram_stopword_False_yes <EOS> <EOS>', '50_most_common_3gram_stopword_False_<BOS> <BOS> lord', 'outlier_score_doc2vec', 'outlier_score_sbert', 'lda_topic_1', 'tfidf_room', 'tfidf_away', 'tfidf_heart', 'tfidf_face', 'keyness_face', 'ratio_of_commas', 'ratio_of_unique_word_trigrams', 'text_length', 'flesch_reading_ease_score', 'unigram_entropy', 'average_paragraph_length', 'doc2vec_chunk_embedding_4', 'doc2vec_chunk_embedding_17', 'doc2vec_chunk_embedding_21', 'doc2vec_chunk_embedding_27', 'doc2vec_chunk_embedding_28', 'doc2vec_chunk_embedding_39', 'doc2vec_chunk_embedding_51', 'doc2vec_chunk_embedding_56', 'doc2vec_chunk_embedding_60', 'doc2vec_chunk_embedding_65', 'doc2vec_chunk_embedding_68', 'doc2vec_chunk_embedding_83', 'doc2vec_chunk_embedding_98']

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

book_and_averaged_chunk_df = pd.read_csv(f"{extracted_features_dir}/{lang}/book_and_averaged_chunk_df.csv")
book_names = book_and_averaged_chunk_df["book_name"].values

book_and_averaged_chunk_df = book_and_averaged_chunk_df.drop(columns=["book_name"])
book_and_averaged_chunk_df = book_and_averaged_chunk_df[[column for column in book_and_averaged_chunk_df.columns if "average_sentence_embedding" not in column]]
best_features = book_and_averaged_chunk_df.columns[np.argwhere((rfe.ranking_ <= 12) == True).T[0]].tolist()
book_and_averaged_chunk_df = book_and_averaged_chunk_df[best_features]

df = book_and_averaged_chunk_df
df["y"] = np.array([labels[book_name] for book_name in book_names])
df["book_name"] = book_names

all_predictions = []
all_labels = []
train_mses = []
train_maes = []
validation_mses = []
validation_maes = []

book_names_splitted = np.array_split(book_names, 10)
for index, split in enumerate(book_names_splitted):
    train_df = df[~df["book_name"].isin(split)]
    validation_df = df[df["book_name"].isin(split)]
    train_X = train_df.drop(columns=["y", "book_name"]).values
    train_y = train_df["y"].values.ravel()
    validation_X = validation_df.drop(columns=["y", "book_name"]).values
    validation_y = validation_df["y"].values.ravel()
    dtrain = xgboost.DMatrix(train_X, label=train_y)
    params = {"max_depth": 4, "learning_rate": 0.03, "colsample_bytree": 0.33, "min_child_weight": 6.0, "n_jobs": -1}
    model = xgboost.train(
        params,
        dtrain,
        num_boost_round=num_boost_round
    )

    train_books = deepcopy(train_df[["book_name", "y"]])
    train_books["yhat"] = model.predict(xgboost.DMatrix(train_X))
    validation_books = deepcopy(validation_df[["book_name", "y"]])
    validation_books["yhat"] = model.predict(xgboost.DMatrix(validation_X))

    train_books = train_books.groupby("book_name").mean()
    validation_books = validation_books.groupby("book_name").mean()

    train_y = train_books["y"].tolist()
    train_yhat = train_books["yhat"].tolist()
    validation_y = validation_books["y"].tolist()
    validation_yhat = validation_books["yhat"].tolist()

    all_labels.extend(validation_y)
    all_predictions.extend(validation_yhat)

    train_mse = mean_squared_error(train_y, train_yhat)
    train_mae = mean_absolute_error(train_y, train_yhat)
    validation_mse = mean_squared_error(validation_y, validation_yhat)
    validation_mae = mean_absolute_error(validation_y, validation_yhat)
    train_mses.append(train_mse)
    train_maes.append(train_mae)
    validation_mses.append(validation_mse)
    validation_maes.append(validation_mae)
    print(f"Fold: {index+1}, TrainMSE: {np.round(train_mse, 3)}, TrainMAE: {np.round(train_mae, 3)}, ValMSE: {np.round(validation_mse, 3)}, ValMAE: {np.round(validation_mae, 3)}")
all_labels = np.array(all_labels)
all_predictions = np.array(all_predictions)

mean_train_mse = np.mean(train_mses)
mean_train_mae = np.mean(train_maes)
mean_validation_mse = np.mean(validation_mses)
mean_validation_mae = np.mean(validation_maes)


print("------")
print(f"Mean scores, TrainMSE: {np.round(mean_train_mse, 3)}, TrainMAE: {np.round(mean_train_mae, 3)}, ValMSE: {np.round(mean_validation_mse, 3)}, ValMAE: {np.round(mean_validation_mae, 3)}")

plt.figure(figsize=(18, 6))
plt.scatter(all_labels, all_predictions)
plt.xlabel("Ground Truths")
plt.ylabel("Predictions")

plt.show();
# Out:
# Fold: 1, TrainMSE: 0.001, TrainMAE: 0.019, ValMSE: 0.04, ValMAE: 0.165
# Fold: 2, TrainMSE: 0.001, TrainMAE: 0.021, ValMSE: 0.037, ValMAE: 0.145
# Fold: 3, TrainMSE: 0.001, TrainMAE: 0.02, ValMSE: 0.034, ValMAE: 0.146
# Fold: 4, TrainMSE: 0.001, TrainMAE: 0.019, ValMSE: 0.062, ValMAE: 0.205
# Fold: 5, TrainMSE: 0.001, TrainMAE: 0.018, ValMSE: 0.034, ValMAE: 0.152
# Fold: 6, TrainMSE: 0.001, TrainMAE: 0.018, ValMSE: 0.032, ValMAE: 0.148
# Fold: 7, TrainMSE: 0.001, TrainMAE: 0.019, ValMSE: 0.049, ValMAE: 0.191
# Fold: 8, TrainMSE: 0.001, TrainMAE: 0.019, ValMSE: 0.04, ValMAE: 0.16
# Fold: 9, TrainMSE: 0.001, TrainMAE: 0.018, ValMSE: 0.046, ValMAE: 0.162
# Fold: 10, TrainMSE: 0.001, TrainMAE: 0.02, ValMSE: 0.021, ValMAE: 0.116
# ------
# Mean scores, TrainMSE: 0.001, TrainMAE: 0.019, ValMSE: 0.039, ValMAE: 0.159
